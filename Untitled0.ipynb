# %%
import cv2
import numpy as np
import glob
original = cv2.imread("/content/drive/MyDrive/images-comparison/images/Y107.jpg")
# Sift and Flann
sift = cv2.xfeatures2d.SIFT_create()
kp_1, desc_1 = sift.detectAndCompute(original, None)
index_params = dict(algorithm=0, trees=5)
search_params = dict()
flann = cv2.FlannBasedMatcher(index_params, search_params)

# Load all the images
all_images_to_compare = []
titles = []
for f in glob.iglob("/content/drive/MyDrive/images-comparison/images/*"):
    image = cv2.imread(f)
    titles.append(f)
    all_images_to_compare.append(image)

for image_to_compare, title in zip(all_images_to_compare, titles):
    # 1) Check if 2 images are equals
    if original.shape == image_to_compare.shape:
        print("The images have same size and channels")
        difference = cv2.subtract(original, image_to_compare)
        b, g, r = cv2.split(difference)
        if cv2.countNonZero(b) == 0 and cv2.countNonZero(g) == 0 and cv2.countNonZero(r) == 0:
            print("Similarity: 100% (equal size and channels)")
            #break
    # 2) Check for similarities between the 2 images
    kp_2, desc_2 = sift.detectAndCompute(image_to_compare, None)
    matches = flann.knnMatch(desc_1, desc_2, k=2)
    good_points = []
    for m, n in matches:
        if m.distance > 0.6*n.distance:
            good_points.append(m)
    number_keypoints = 0
    if len(kp_1) >= len(kp_2):
        number_keypoints = len(kp_1)
    else:
        number_keypoints = len(kp_2)
    print("Title: " + title)
    percentage_similarity = len(good_points) / number_keypoints * 100
    print("Similarity: " + str(int(percentage_similarity)) + "\n")
# Out:
# Title: /content/drive/MyDrive/images-comparison/images/Y169.jpg
# Similarity: 84
#
# Title: /content/drive/MyDrive/images-comparison/images/Y107 (1).jpg
# Similarity: 11
#
# Title: /content/drive/MyDrive/images-comparison/images/Y8.jpg
# Similarity: 67
#
# Title: /content/drive/MyDrive/images-comparison/images/Y79.jpg
# Similarity: 99
#
# Title: /content/drive/MyDrive/images-comparison/images/Y56.jpg
# Similarity: 98
#
# Title: /content/drive/MyDrive/images-comparison/images/Y45.JPG
# Similarity: 99
#
# Title: /content/drive/MyDrive/images-comparison/images/Y49.JPG
# Similarity: 55
#
# Title: /content/drive/MyDrive/images-comparison/images/Y77.jpg
# Similarity: 74
#
# Title: /content/drive/MyDrive/images-comparison/images/Y44.JPG
# Similarity: 87
#
# Title: /content/drive/MyDrive/images-comparison/images/Y66.JPG
# Similarity: 100
#
# Title: /content/drive/MyDrive/images-comparison/images/Y69.jpg
# Similarity: 57
#
# Title: /content/drive/MyDrive/images-comparison/images/Y37.jpg
# Similarity: 76
#
# Title: /content/drive/MyDrive/images-comparison/images/Y67.JPG
# Similarity: 83
#
# Title: /content/drive/MyDrive/images-comparison/images/Y32.jpg
# Similarity: 99
#
# Title: /content/drive/MyDrive/images-comparison/images/Y70.jpg
# Similarity: 88
#
# Title: /content/drive/MyDrive/images-comparison/images/Y78.jpg
# Similarity: 100
#
# Title: /content/drive/MyDrive/images-comparison/images/Y89.JPG
# Similarity: 99
#
# Title: /content/drive/MyDrive/images-comparison/images/Y62.jpg
# Similarity: 98
#
# Title: /content/drive/MyDrive/images-comparison/images/Y35.jpg
# Similarity: 67
#
# Title: /content/drive/MyDrive/images-comparison/images/Y61.jpg
# Similarity: 31
#
# Title: /content/drive/MyDrive/images-comparison/images/Y76.jpg
# Similarity: 62
#
# Title: /content/drive/MyDrive/images-comparison/images/Y53.jpg
# Similarity: 99
#
# Title: /content/drive/MyDrive/images-comparison/images/Y30.jpg
# Similarity: 88
#
# Title: /content/drive/MyDrive/images-comparison/images/Y73.jpg
# Similarity: 77
#
# Title: /content/drive/MyDrive/images-comparison/images/Y60.jpg
# Similarity: 98
#
# Title: /content/drive/MyDrive/images-comparison/images/Y42.jpg
# Similarity: 100
#
# Title: /content/drive/MyDrive/images-comparison/images/Y65.JPG
# Similarity: 99
#
# Title: /content/drive/MyDrive/images-comparison/images/Y85.JPG
# Similarity: 100
#
# Title: /content/drive/MyDrive/images-comparison/images/Y86.JPG
# Similarity: 100
#
# Title: /content/drive/MyDrive/images-comparison/images/Y54.jpg
# Similarity: 88
#
# Title: /content/drive/MyDrive/images-comparison/images/Y46.jpg
# Similarity: 59
#
# Title: /content/drive/MyDrive/images-comparison/images/Y75.JPG
# Similarity: 100
#
# Title: /content/drive/MyDrive/images-comparison/images/Y33.jpg
# Similarity: 11
#
# Title: /content/drive/MyDrive/images-comparison/images/Y38.jpg
# Similarity: 88
#
# Title: /content/drive/MyDrive/images-comparison/images/Y47.JPG
# Similarity: 76
#
# Title: /content/drive/MyDrive/images-comparison/images/Y39.jpg
# Similarity: 79
#
# Title: /content/drive/MyDrive/images-comparison/images/Y55.jpg
# Similarity: 31
#
# Title: /content/drive/MyDrive/images-comparison/images/Y41.jpg
# Similarity: 27
#
# Title: /content/drive/MyDrive/images-comparison/images/Y58.JPG
# Similarity: 99
#
# Title: /content/drive/MyDrive/images-comparison/images/Y74.jpg
# Similarity: 31
#
# Title: /content/drive/MyDrive/images-comparison/images/Y40.JPG
# Similarity: 99
#
# Title: /content/drive/MyDrive/images-comparison/images/Y52.jpg
# Similarity: 50
#
# Title: /content/drive/MyDrive/images-comparison/images/Y31.jpg
# Similarity: 98
#
# Title: /content/drive/MyDrive/images-comparison/images/Y71.JPG
# Similarity: 65
#
# Title: /content/drive/MyDrive/images-comparison/images/Y59.JPG
# Similarity: 84
#
# Title: /content/drive/MyDrive/images-comparison/images/Y82.jpg
# Similarity: 99
#
# Title: /content/drive/MyDrive/images-comparison/images/Y50.JPG
# Similarity: 99
#
# Title: /content/drive/MyDrive/images-comparison/images/Y81.jpg
# Similarity: 99
#
# Title: /content/drive/MyDrive/images-comparison/images/Y51.jpg
# Similarity: 76
#
# Title: /content/drive/MyDrive/images-comparison/images/Y34.jpg
# Similarity: 64
#
# Title: /content/drive/MyDrive/images-comparison/images/Y13.jpg
# Similarity: 84
#
# The images have same size and channels
# Similarity: 100% (equal size and channels)
# Title: /content/drive/MyDrive/images-comparison/images/Y107.jpg
# Similarity: 0
#
# Title: /content/drive/MyDrive/images-comparison/images/Y36.JPG
# Similarity: 99

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.5.5.62-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (66.6 MB)
#      |████████████████████████████████| 66.6 MB 157 kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-contrib-python) (1.21.5)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.5.5.62
